# %%
1+2-3
# Out:
# 0

# %%
2*3/7+3^2
# Out:
# 69/7

# %%
(sqrt(3.))
# Out:
# 1.73205080756888

# %%
numerical_approx(pi)
# Out:
# 3.14159265358979

# %%
sin(0.1)
# Out:
# 0.0998334166468282

# %%
x=var('x')
p1=(x^2+2*x-1)^3*(x^2-2)
p1.expand()
# Out:
# x^8 + 6*x^7 + 7*x^6 - 16*x^5 - 27*x^4 + 14*x^3 + 17*x^2 - 12*x + 2

# %%
x=var('x')
n=var('n')
p1=(x+n)^5
p1.expand()
# Out:
# n^5 + 5*n^4*x + 10*n^3*x^2 + 10*n^2*x^3 + 5*n*x^4 + x^5

# %%
p2=x^8-1
p2.factor()
# Out:
# (x^4 + 1)*(x^2 + 1)*(x + 1)*(x - 1)

# %%
x=var('x')
p3=2*x^2/(x^3-1)+3*x/(x^2-1)
p3.factor()
# Out:
# (5*x^2 + 5*x + 3)*x/((x^2 + x + 1)*(x + 1)*(x - 1))

# %%
p4=sin(x)^2+cos(x)^2
p4.trig_simplify()
# Out:
# 1

# %%
p5=exp(x)+log(x,e)
p5.subs(x=1)
# Out:
# e

# %%
p6=x^2-4*x+3==0
solve(p6,x)
# Out:
# [x == 3, x == 1]

# %%
y=var('y')
p7=x^2*y+2*y-x==0
solve(p7,y)
# Out:
# [y == x/(x^2 + 2)]

# %%
y=var('y')
p7=x^2*y+2*y-x==0
solve(p7,x)
# Out:
# [x == -1/2*(sqrt(-8*y^2 + 1) - 1)/y, x == 1/2*(sqrt(-8*y^2 + 1) + 1)/y]

# %%
p8=x-cos(x)==0
find_root(p8,-1,1)
# Out:
# 0.7390851332151607

# %%
p9=x^5-3*x^3-1==0
find_root(p9,-2,2)
# Out:
# 1.7823087800458834

# %%
syst=[4*x+3*y==10,3*x-y==1]
solve(syst,x,y)
# Out:
# [[x == 1, y == 2]]

# %%
g(x)=exp(x)-sin(x)
g.subs(x=0)
# Out:
# x |--> 1

# %%
a=diff(g(x),x)
a.expand()
# Out:
# -cos(x) + e^x

# %%
a.subs(x=0)
# Out:
# 0

# %%
integrate(g(x),x)
# Out:
# cos(x) + e^x

# %%
integrate(g(x),x,-1,1)
# Out:
# (e^2 - 1)*e^(-1)

# %%
b=diff(g(x),x,2)
b.expand()
# Out:
# e^x + sin(x)

# %%
b.subs(x=0)
# Out:
# 1

# %%
limit(sin(x)/x,x=0)
# Out:
# 1

# %%
limit((cos(x)+1)/(x+pi),x=pi)
# Out:
# 0

# %%
plot(sin(x),0,2*pi)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(1/x,-1,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
parametric_plot((2-t^2,t-t^3),(t,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((cos(t),sin(t)),(t,0,pi/6))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((cos(t),sin(t)),(t,0,pi/3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((cos(t),sin(t)),(t,0,pi/2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((cos(t),sin(t)),(t,0,pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((cos(t),sin(t)),(t,0,3*pi/2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((cos(t),sin(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((cos(t),sin(t)),(t,0,4*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((2*cos(t/3),2*sin(t/3)),(t,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((2*cos(t/3),2*sin(t/3)),(t,0,4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((2*cos(t/3),2*sin(t/3)),(t,-pi,pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x,y)=x^2-2*x*y-y^2==1
implicit_plot(f(x,y),(x,0,pi),(y,-pi,pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
h(x,y)=x^2+y^2
plot3d(h(x,y)==1,(x,-pi,pi),(y,-pi,pi))
# Out:
# Graphics3d Object
